# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")

# %%
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000002265715D750>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002265715F790>, root_client=<openai.OpenAI object at 0x000002265D6C6A40>, root_async_client=<openai.AsyncOpenAI object at 0x000002265715D780>, model_name='gpt-4o', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
llm.invoke("What is generative ai?")
# Out:
# AIMessage(content='Generative AI refers to a category of artificial intelligence systems designed to create new content. This capability is typically fostered through learning patterns and structures from input data, enabling the system to generate outputs that mimic or extend these patterns. Unlike traditional AI systems that focus on recognizing and classifying data, generative AI can produce novel data, such as images, text, music, or even entire virtual environments.\n\nKey types of generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** These systems consist of two neural networks, a generator and a discriminator, that are trained together. The generator creates new content, while the discriminator evaluates it against real data. Through this adversarial process, the generator improves its outputs over time.\n\n2. **Variational Autoencoders (VAEs):** These models learn to encode input data into a latent space and then decode from this space to generate new instances similar to the input data.\n\n3. **Transformer-based Models:** These models, like GPT (Generative Pre-trained Transformer), can generate human-like text by predicting the next word in a sentence based on the context of previous words.\n\nGenerative AI has a wide range of applications, including content creation, music and art generation, natural language processing, drug discovery, and more. It offers exciting possibilities but also poses challenges such as ethical considerations and the potential for misuse in creating deepfakes or generating misleading information.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 287, 'prompt_tokens': 13, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_726d488742', 'id': 'chatcmpl-BNO3pElQ8JR3X2dnG4450I6Hj3QVz', 'finish_reason': 'stop', 'logprobs': None}, id='run-fde1159b-3d7a-435f-9985-9708c38d13e1-0', usage_metadata={'input_tokens': 13, 'output_tokens': 287, 'total_tokens': 300, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a platform developed by the team behind LangChain, a popular framework for building applications with large language models. Langsmith provides robust tools for the testing and debugging of language model applications, making it easier for developers to ensure that their applications behave as expected. It offers a suite of features to streamline the development process, including detailed logging and tracing of language model interactions, the ability to visualize and analyze these interactions, and tools for evaluating application performance. Langsmith is particularly useful for developers working on complex applications that require reliable and predictable integrations with language models, as it aims to enhance the efficiency of development workflows and improve application reliability.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 128, 'prompt_tokens': 33, 'total_tokens': 161, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_f5bdcc3276', 'id': 'chatcmpl-BNO4CrywPAC0aTeZ9lSjopjONKPyv', 'finish_reason': 'stop', 'logprobs': None} id='run-ddf04156-7802-4931-ad41-90790290c4b5-0' usage_metadata={'input_tokens': 33, 'output_tokens': 128, 'total_tokens': 161, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"You know my name?"})
print(response)
# Out:
# No, I don't have access to personal data about individuals unless it has been shared with me in the course of our conversation. Therefore, I don't know your name unless you tell me.
